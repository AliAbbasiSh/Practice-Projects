# %%
import pandas_datareader as pdd
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
# %matplotlib inline

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
BAC = pdd.DataReader("BAC", 'yahoo', start, end)
C = pdd.DataReader("C", 'yahoo', start, end)
GS = pdd.DataReader("GS", 'yahoo', start, end)
JPM = pdd.DataReader("JPM", 'yahoo', start, end)
MS = pdd.DataReader("MS", 'yahoo', start, end)
WFC = pdd.DataReader("WFC", 'yahoo', start, end)

# %%
MS
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  35.558968
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  35.583351
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  35.680912
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  35.717510
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  36.095612
# ...               ...        ...        ...        ...        ...        ...
# 2015-12-24  32.709999  32.439999  32.570000  32.480000  2798200.0  27.602324
# 2015-12-28  32.360001  31.950001  32.360001  32.169998  5420300.0  27.338877
# 2015-12-29  32.700001  32.330002  32.439999  32.549999  6388200.0  27.661810
# 2015-12-30  32.650002  32.200001  32.500000  32.230000  5057200.0  27.389866
# 2015-12-31  32.299999  31.770000  31.910000  31.809999  8154300.0  27.032938
#
# [2517 rows x 6 columns]

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.584072
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.227406
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.270210
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.220261
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.241665
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.193917
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.070746
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.202712
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.000361
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
# ...                ...        ...        ...        ...         ...
# 2015-12-24   17.379999  17.219999  17.320000  17.270000  29369400.0
# 2015-12-28   17.230000  16.980000  17.219999  17.129999  41777500.0
# 2015-12-29   17.350000  17.160000  17.250000  17.280001  45670400.0
# 2015-12-30   17.240000  17.040001  17.200001  17.049999  35066400.0
# 2015-12-31   17.070000  16.830000  17.010000  16.830000  47153000.0
#
# ...

# %%
bank_stocks.xs(key="Close",axis=1,level="Stock Info").max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick + "Return"]=bank_stocks[tick]["Close"].pct_change()
returns
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158
# ...               ...       ...       ...        ...       ...        ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681  -0.003997
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544  -0.002554
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812   0.011156
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831  -0.007235
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031  -0.009656
#
# [2517 rows x 6 columns]

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACReturn    0.036647
# CReturn      0.038672
# GSReturn     0.025390
# JPMReturn    0.027667
# MSReturn     0.037819
# WFCReturn    0.030238
# dtype: float64

# %%
returns.loc["2015-01-01":"2015-12-31"].std()
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %%
sns.displot(returns.loc["2015-01-01":"2015-12-31"]["MSReturn"],bins=50)

# %%
sns.displot(returns.loc["2008-01-01":"2008-12-31"]["CReturn"],bins=50)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
for tick in tickers:
    bank_stocks[tick]["Close"].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
bank_stocks.xs(key="Close",axis=1,level="Stock Info").plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
BAC['Close'].loc["2008-01-01":"2009-01-01"].rolling(window=30).mean().plot()
BAC['Close'].loc["2008-01-01":"2009-01-01"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.heatmap(bank_stocks.xs(key="Close",axis=1,level="Stock Info").corr())
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key="Close",axis=1,level="Stock Info").corr())
